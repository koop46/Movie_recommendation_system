# %% [markdown]
# ### Content filter
# - Items with same characteristics: watch 1 Tom Hanks movie, get more Tom Hanks movies recommended
# - Requires item attribute info
#
# ### Collaborative filter:
# - Similar items that user has liked: See movie about dinosaurs, see action or adventures moves recommended
# - Requires user-item interaction data

# %%
import polars as pl

movies_df = pl.read_csv("ml-latest/movies.csv")

ratings_df = pl.read_csv("ml-latest/ratings.csv")

tags_df = pl.read_csv("ml-latest/tags.csv")

movies_df.shape, ratings_df.shape, tags_df.shape
# Out:
# ((86537, 3), (33832162, 4), (2328315, 4))

# %%
movies_df = (
    movies_df.with_columns(
        
        pl.col("genres").str.replace_all(r"\|", ", "),          # Replace pipe "|" separators with commas (no list splitting)
        pl.col("title").str.extract_groups(
            r'^(?P<title>.*?)\s*\((?P<year>\d{4})\)\s*$'        # Extract title and year from the "title" column
        )
    )
    .unnest("title")                                            # Split into "title" and "year" columns
    .with_columns(

        pl.col("year").cast(pl.Int32, strict=False)
    )
)


movies_df = movies_df[:-17]                                     # cut off tail to be merged with other dfs

movies_df
# Out:
# shape: (86_520, 4)
# ┌─────────┬─────────────────────────────┬──────┬─────────────────────────────────┐
# │ movieId ┆ title                       ┆ year ┆ genres                          │
# │ ---     ┆ ---                         ┆ ---  ┆ ---                             │
# │ i64     ┆ str                         ┆ i32  ┆ str                             │
# ╞═════════╪═════════════════════════════╪══════╪═════════════════════════════════╡
# │ 1       ┆ Toy Story                   ┆ 1995 ┆ Adventure, Animation, Children… │
# │ 2       ┆ Jumanji                     ┆ 1995 ┆ Adventure, Children, Fantasy    │
# │ 3       ┆ Grumpier Old Men            ┆ 1995 ┆ Comedy, Romance                 │
# │ 4       ┆ Waiting to Exhale           ┆ 1995 ┆ Comedy, Drama, Romance          │
# │ 5       ┆ Father of the Bride Part II ┆ 1995 ┆ Comedy                          │
# │ …       ┆ …                           ┆ …    ┆ …                               │
# │ 288923  ┆ Maximum Truth               ┆ 2023 ┆ Comedy                          │
# │ 288927  ┆ null                        ┆ null ┆ Comedy                          │
# │ 288931  ┆ V for Vengeance             ┆ 2022 ┆ Action, Horror                  │
# │ 288935  ┆ Kosovolove                  ┆ 2000 ┆ (no genres listed)              │
# │ 288937  ┆ Blue Thermal                ┆ 2022 ┆ Animation, Comedy, Drama, Roma… │
# └─────────┴─────────────────────────────┴──────┴─────────────────────────────────┘

# %%
tags_df = tags_df.with_columns(pl.from_epoch(pl.col("timestamp"), time_unit="s"))


tags_df = (
    tags_df
    .group_by("movieId")
    .agg(

        pl.col("tag").str.concat(", ").alias("tag_list")
    )
    .sort("movieId")
)


tags_df = tags_df[:-1]                                                          # cut off to better merge with other dfs

tags_df
# Out:
# shape: (53_451, 2)
# ┌─────────┬─────────────────────────────────┐
# │ movieId ┆ tag_list                        │
# │ ---     ┆ ---                             │
# │ i64     ┆ str                             │
# ╞═════════╪═════════════════════════════════╡
# │ 1       ┆ animation, friendship, toys, a… │
# │ 2       ┆ animals, based on a book, fant… │
# │ 3       ┆ sequel, moldy, old, old age, o… │
# │ 4       ┆ characters, chick flick, girl … │
# │ 5       ┆ family, pregnancy, wedding, 4t… │
# │ …       ┆ …                               │
# │ 288753  ┆ deep web, horror, thriller      │
# │ 288765  ┆ post-apocalyptic, survival, tw… │
# │ 288779  ┆ Don Camillo Series              │
# │ 288849  ┆ addiction, animation, short fi… │
# │ 288937  ┆ anime                           │
# └─────────┴─────────────────────────────────┘

# %%
ratings_df = (
    ratings_df
    .group_by("movieId")
    .agg(
        pl.col("rating").mean().alias("average_rating")
    )
    .sort("movieId")
)

ratings_df
# Out:
# shape: (83_239, 2)
# ┌─────────┬────────────────┐
# │ movieId ┆ average_rating │
# │ ---     ┆ ---            │
# │ i64     ┆ f64            │
# ╞═════════╪════════════════╡
# │ 1       ┆ 3.893508       │
# │ 2       ┆ 3.278179       │
# │ 3       ┆ 3.171271       │
# │ 4       ┆ 2.868395       │
# │ 5       ┆ 3.076957       │
# │ …       ┆ …              │
# │ 288967  ┆ 3.5            │
# │ 288971  ┆ 0.5            │
# │ 288975  ┆ 4.0            │
# │ 288977  ┆ 3.0            │
# │ 288983  ┆ 3.0            │
# └─────────┴────────────────┘

# %%
combined_df = (
    tags_df
    .join(ratings_df, on="movieId")
    .join(movies_df, on="movieId")
    .drop_nulls()
    .sort("movieId")
)

combined_df = combined_df.filter(pl.col("genres") != "(no genres listed)")

# %%
def text_representation(row: dict) -> str:
    return (
        f"""Title: {row['title']},
Year: {row['year']}, 
Genre: {row['genres']}, 
Tags: {row['tag_list']},
Ratings: {row['average_rating']}"""
    )

# %%
combined_df = combined_df.with_columns([
    pl.struct(["tag_list", "average_rating", "title", "year", "genres"])
      .map_elements(lambda x: text_representation(x))  
      .alias("embedding_text")
])
# Out:
# C:\Users\Ale\AppData\Local\Temp\ipykernel_11712\3395396005.py:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   combined_df = combined_df.with_columns([

# %%
combined_df


combined_df.write_csv("clean_data.csv")

# %%
combined_df = combined_df.filter((pl.col("year") >= 1950) & (pl.col("average_rating") >= 3.0) )

combined_df.shape
# Out:
# (27646, 7)

# %%
combined_df["embedding_text"][3]
# Out:
# "Title: Father of the Bride Part II,\nYear: 1995, \nGenre: Comedy, \nTags: family, pregnancy, wedding, 4th wall, aging, baby, daughter, Diane Keaton, family, father, father - child relationship, fourth wall, growing old, gynecologist, heartwarming, humorous, midlife crisis, narration, parent child relationship, pregnancy, regret, seen 2021, seen more than once, sentimental, sequel, Steve Martin, humorous, steve martin, childhood classics, it thought it was funny but it wasn't, watched under duress, worst movies ever, Diane Keaton, family, sequel, Steve Martin, wedding, steve martin, steve martin, childhood classics, steve martin, Comedy, Diane Keaton, family, pregnancy, steve martin, Touching, sequel fever, CLV, Steve Martin, aging, baby, confidence, contraception, daughter, gynecologist, midlife crisis, parent child relationship, pregnancy, pregnancy, remake, Comedy, Touching, steve martin, Steve Martin, family, Steve Martin, Fantasy,\nRatings: 3.0769571546104677"

# %%
import faiss
import numpy as np

dim = 384
index = faiss.IndexFlatL2(dim)
X = np.zeros((len(combined_df["embedding_text"]), dim), dtype="float32")

# %%
from sentence_transformers import SentenceTransformer
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"                     # Enable GPU acceleration
model = SentenceTransformer('all-MiniLM-L6-v2', device=device)

model = model.half()                                                        # Reduces memory usage by 50%

batch_size = 128                                                           


loader_params = {
    "batch_size": batch_size,
    "num_workers": 12,        
    "pin_memory": True,      
    "persistent_workers": True
}


embeddings = model.encode(
    combined_df["embedding_text"].to_numpy(),
    **loader_params,
    convert_to_numpy=True,   
    show_progress_bar=True,
    normalize_embeddings=True  
)
# Add to index
index.add(embeddings)
# Out:
# Batches: 100%|██████████| 216/216 [00:13<00:00, 16.39it/s]

# %%
# Save vector database

faiss.write_index(index, "index-vdb")

# %%
# import faiss

# # Load vector database

# index = faiss.read_index("index-vdb")

# %%
df = combined_df

df.filter(pl.col("title").str.contains("Shutter"))
# Out:
# shape: (4, 7)
# ┌─────────┬─────────────────┬─────────────────┬─────────────────┬──────┬──────────┬────────────────┐
# │ movieId ┆ tag_list        ┆ average_rating  ┆ title           ┆ year ┆ genres   ┆ embedding_text │
# │ ---     ┆ ---             ┆ ---             ┆ ---             ┆ ---  ┆ ---      ┆ ---            │
# │ i64     ┆ str             ┆ f64             ┆ str             ┆ i32  ┆ str      ┆ str            │
# ╞═════════╪═════════════════╪═════════════════╪═════════════════╪══════╪══════════╪════════════════╡
# │ 45003   ┆ easily confused ┆ 3.423658        ┆ Shutter         ┆ 2004 ┆ Fantasy, ┆ Title:         │
# │         ┆ with other mov… ┆                 ┆                 ┆      ┆ Horror,  ┆ Shutter,       │
# │         ┆                 ┆                 ┆                 ┆      ┆ Mystery, ┆ Year: 2004,    │
# │         ┆                 ┆                 ┆                 ┆      ┆ Thri…    ┆ G…             │
# │ 74458   ┆ Leonardo        ┆ 4.002853        ┆ Shutter Island  ┆ 2010 ┆ Drama,   ┆ Title: Shutter │
# │         ┆ DiCaprio,       ┆                 ┆                 ┆      ┆ Mystery, ┆ Island,        │
# │         ┆ psychologic…    ┆                 ┆                 ┆      ┆ Thriller ┆ Year: 2…       │
# │ 127632  ┆ curse, fire,    ┆ 3.0             ┆ The Shuttered   ┆ 1967 ┆ Horror   ┆ Title: The     │
# │         ┆ lighthouse,     ┆                 ┆ Room            ┆      ┆          ┆ Shuttered      │
# │         ┆ mill,…          ┆                 ┆                 ┆      ┆          ┆ Room,          │
# │         ┆                 ┆                 ┆                 ┆      ┆          ┆ Yea…           │
# │ 149026  ┆ car driver,     ┆ 3.6             ┆ Shutter         ┆ 2013 ┆ Thriller ┆ Title:         │
# │         ┆ city,           ┆                 ┆                 ┆      ┆          ┆ Shutter,       │
# │         ┆ friendship, …   ┆                 ┆                 ┆      ┆          ┆ Year: 2013,    │
# │         ┆                 ┆                 ┆                 ┆      ┆          ┆ G…             │
# └─────────┴─────────────────┴─────────────────┴─────────────────┴──────┴──────────┴────────────────┘

# %%
fav_movie = df.filter(pl.col("movieId") == 74458)
fav_movie.glimpse()
# Out:
# Rows: 1
# Columns: 7
# $ movieId        <i64> 74458
# $ tag_list       <str> "Leonardo DiCaprio, psychological, twist ending, asylum, mystery, story, twist ending, mystery, thought-provoking, twist ending, plot twist, psychological, twist ending, clever, mindfuck, stylized, thought-provoking, twist ending, cinematography, ending twist, Leonardo DiCaprio, Martin Scorsese, mindfuck, shocking ending, thought-provoking, twist ending, World War II, action, ending twist, Predictable, psychological, story, too long, Leonardo DiCaprio, Martin Scorsese, mental illness, mystery, plot twist, predictable, asylum, atmospheric, cinematography, clever, ending twist, insanity, intense, Leonardo DiCaprio,
pointless plot, sci-fi, sci-fi thriller, science fiction, telekinesis, tense, thriller, time travel, unlikeable characters, violent, visually appealing, Bruce Willis, Joseph Gordon-Levitt, time travel, clever, time travel, clever, dystopia, film noir, sci-fi, time travel, bad science, mother-son relationship, original, paranormal, sci-fi, science fiction, time travel, memasa's movies, bad science, dystopia, Nudity (Topless), plot holes, sci-fi, science fiction, time travel, time travel, bad science, Bruce Willis, plot holes, pointless plot, sci-fi, time travel, Bruce Willis, Character study, clever, dystopia, Emily Blunt, film noir, future, hitman, Joseph Gordon-Levitt, Kansas, mother-son relationship, Noah Segan, organized crime, Paul Dano, Rian Johnson, Shanghai, telekinesis, time travel, visually appealing, Bruce Willis, dystopia, Joseph Gordon-Levitt, sci-fi, time travel, Bruce Willis, Character study, Joseph Gordon-Levitt, sci-fi, time travel, visually appealing, bad science, time travel, Bruce Willis, clever, dystopia, film noir, gore, time travel, clever, dystopia, sci-fi, time travel, Bechdel Test:Fail, dystopian, killer as protagonist, memory, murder, organized crime, painfully heteronormative, paranormal, setting:Kansas, setting:Shanghai, suicide, time travel, tragedy, utterly pedestrian cinematography, violent, future, sci-fi, time travel, pointless plot, Bruce Willis, dystopia, Joseph Gordon-Levitt, organized crime, time travel, clever, dystopia, sci-fi, time travel, visually appealing, bad science, plot holes, pointless plot, sci-fi, sci-fi thriller, time travel, visually appealing, paranormal, Bruce Willis, bad science, plot holes, clever, complicated, Nudity (Topless), complicated, great script, original, telekinesis, sci-fi, time travel, violent, sci-fi, dystopia, sci-fi, great script, Bruce Willis, Joseph Gordon-Levitt, sci-fi, time travel, clever, dystopia, film noir, future, organized crime, plot holes, thriller, time travel, visually appealing, paranormal, time travel, time travel, film noir, visually appealing, bad science, Bruce Willis, clever, complicated, dystopia, film noir, future, great script, hitman, organized crime, original, plot holes, pointless plot, sci-fi, sci-fi thriller, tense, thriller, time travel, unlikeable characters, violence, visually appealing, Bruce Willis, creepy kid, dystopia, emily blunt, grandfather paradox, hitman, Joseph Gordon-Levitt, organized crime, sci-fi, science fiction, time travel, na dysku, clever, dystopia, time travel, visually appealing, clever, dystopia, future, plot holes, tense, time travel, visually appealing, Bruce Willis, dystopia, film noir, good writing, sci-fi, sci-fi thriller, science fiction, tense, thriller, time travel, visually appealing, gore, Nudity (Topless), plot holes, pointless plot, time travel, violence, Bruce Willis, future, Joseph Gordon-Levitt, bad science, character study, Emily Blunt, film noir, Joseph Gordon-Levitt, Nudity (Topless), telekinesis, clever, complicated, dystopia, Emily Blunt, film noir, great script, Joseph Gordon-Levitt, original, sci-fi, sci-fi thriller, time travel, visually appealing, sci-fi, Bruce Willis, organized crime, sci-fi, bad makeup, dumb, great ending, complicated plot, sci-fi, thriller, time travel, violent, visually appealing, bad science, boring, film noir, jeff daniels, Nudity (Topless), plot holes, pointless plo ...
# Ratings: 3.6541864764923404

# %%
ddd = pl.read_csv("normalized_tags.csv")
ddd = ddd["cleaned_tags"].unique()
dd = pl.col("cleaned_tags").is_not_null()
dd



# dd.write_csv("normalized_tags.csv")
# Out:
# <Expr ['col("cleaned_tags").is_not_nul…'] at 0x25401E95850>

# %%
df.write_csv("clean_data.csv")
